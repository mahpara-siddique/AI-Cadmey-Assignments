# %% [markdown]
# **Input and Type Casting**

# %% [markdown]
# **Input**

# %%
username = input("Enter your username: ")
password = input("Enter your password: ")
encryption = input("Enter text fot encryption: ")
decryption = input("Enter decyption code: ")
error = input("Tell about error in one line: ")
net = input("Do you want to scan the network? ")
network = input("Which network you are using right now? ")
port = input("Which port is open currently? ")
switch = input("Describe the role of switch: ")
kali = input("Are you familiar with kali? ")
linux = input("Give your feedback about linux: ")
ubuntu = input("Do you know ubuntu is the distro of linux? ")
hack = input("Will you use your hacking skills ethically? (yes/no)")
attack = input("Do you know about ddos attack? ")
firewall = input("Enter your firewall status (enabled/disabled): ")
vpn = input("VPNs are not safe to use , agree? ")
shell = int(input("Enter your port_number"))
digit =int(input("Enter any digit from 1-100"))
binary =int(input("Write something in 0s & 1s: "))
log_file = float(input("How many log files do you have? "))
log_name = float(input("How many digits are there in your name: "))
pass_key = float(input("Tell the length of your pass key: "))
packet =float(input("How many payload packets have you sent till now? "))
data = float(input("Enter 3 digit smallest number: "))
router = bool(int(input("Is your system secure? (1 for True, 0 for False): ")))
isp = bool(int(input("is your ISP trust worthy? (1 for True, 0 for False): ")))
attempt =bool(int(input("Is MFA enabled? (1 for True, 0 for False)")))
scan =bool(str(input("Is youe system secure? (yes for True, no for False): ")))
lost = bool(int(input("Is backup completed? (1 for True, 0 for False): ")))
format =bool(int(input("Is your system updated? (1 for True, 0 for False): ")))
print(username)
print(password)
print(encryption)
print(decryption)
print(error)
print(net)
print(network)
print(port)
print(switch)
print(kali)
print(linux)
print(ubuntu)
print(hack)
print(attack)
print(firewall)
print(vpn)
print(shell)
print(digit)
print(binary)
print(log_file)
print(log_name)
print(pass_key)
print(packet)
print(data)
print(router)
print(isp)
print(attempt)
print(scan)
print(lost)
print(format)

# %% [markdown]
# **Type Casting**

# %%
#string to integer
mercury = "123456"
mercury_int = int(mercury)
venus =  "4321"
venus_int = int(venus)
earth = "786"
earth_int = int(earth)
# string to float
mars = "3.55"
mars_f = float(mars)
jupiter = "9.0"
jupiter_f = float(jupiter)
saturn = "396"
saturn_f = float(saturn)
# integer to string
uranus = 808080
uranus_st = str(uranus)
neptune = 256
neptune_str = str(neptune)
pluto = 200
pluto_str = str(pluto)
# float to string
milky_way = 99.5
milky_wayf = str(milky_way)
andro_meda = 55.5
andro_medaf = str(andro_meda)
# integer to boolean
star = 55
star_bl = bool(star)
moon = 332
moon_bl = bool(moon)
sun = 00
sun_bl = bool(sun)
# boolean to integer
black_hole = True
black_holei = int(black_hole)
blanet = False
blanet_i = int(blanet)
planet = True
planet_i = int(planet)
# float to integer
gravity = 88.9
gravity_i = int(gravity)
apes = 22.4
apes_i = int(apes)
chimpanzee = 555.5
chimpanzee_i = int(chimpanzee)
# integer to float
galapagos = 55
galapagos_f = float(galapagos)
iland = 898
iland_f = float(iland)
space =333
space_f = float(space)
vacuum = 3
vacuum_f = float(vacuum)
rover = 88
rover_f = float(rover)
robot = 77
robot_f = float(robot)
alien = 87
alien_f = float(alien)
sci_fi = 54
sci_fif = float(sci_fi)
tenet = 34
tenet_f = float(tenet)
inter_steller = 22
inter_stellerf = float(inter_steller)
print(mercury_int)
print(venus_int)
print(earth_int)
print(mars_f)
print(jupiter_f)
print(saturn_f)
print(uranus_st)
print(neptune_str)
print(pluto_str)
print(milky_wayf)
print(andro_medaf)
print(star_bl)
print(moon_bl)
print(sun_bl)
print(black_holei)
print(blanet_i)
print(planet_i)
print(gravity_i)
print(apes_i)
print(chimpanzee_i)
print(galapagos_f)
print(iland_f)
print(space_f)
print(vacuum_f)
print(rover_f)
print(robot_f)
print(alien_f)
print(sci_fif)
print(tenet_f)
print(inter_stellerf)
# Out:
# 123456
# 4321
# 786
# 3.55
# 9.0
# 396.0
# 808080
# 256
# 200
# 99.5
# 55.5
# True
# True
# False
# 1
# 0
# 1
# 88
# 22
# 555
# 55.0
# 898.0
# 333.0
# 3.0
# 88.0
# 77.0
# 87.0
# 54.0
# 34.0
# 22.0
