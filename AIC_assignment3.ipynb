# %% [markdown]
# **arithmatic Operators**

# %% [markdown]
# **Addition**

# %%
# example1
attack1 = 10
attack2 = 10
print ("Addition:" , attack1+attack2)
# example2
server_alpha = 50
server_beta  = 50
print ("Addition:" , server_alpha+server_beta)
# example3
num1 = 100
num2 = 100
print ("Addition:" , num1+num2)
# example4
fire_wall = 500
fire_ball = 500
print ("Addition:" , fire_wall+fire_ball)
# example5
ddos = 100
dos = 10
print ("Addition:" , ddos+dos)
# Out:
# Addition: 20
# Addition: 100
# Addition: 200
# Addition: 1000
# Addition: 110

# %% [markdown]
# **Subtraction**

# %%
# example1
attack1 = 1000
attack2 = 10
print ("Subtraction:" , attack1-attack2)
# example2
server_alpha = 35
server_beta  = 50
print ("Subtraction:" , server_alpha-server_beta)
# example3
num1 = 700
num2 = 100
print ("Subtraction:" , num1-num2)
# example4
fire_wall = 530
fire_ball = 500
print ("Subtraction:" , fire_wall-fire_ball)
# example5
ddos = 100
dos = 10
print ("Subtraction:" , ddos-dos)
# Out:
# Subtraction: 990
# Subtraction: -15
# Subtraction: 600
# Subtraction: 30
# Subtraction: 90

# %% [markdown]
# **Multiplication**

# %%
# example1
vpn = 2
VPN = 8
print ("Multipliaction:" , vpn*VPN)
# example2
encryption = 35
decryption  = 55
print ("Multipliaction:" , encryption*decryption)
# example3
num1 = 700
num2 = 100
print ("Multipliaction:" , num1*num2)
# example4
mat_lab = 530
MAT_LAB = 500
print ("Multipliaction:" , mat_lab*MAT_LAB)
# example5
WIRE_SHARK = 100
wire_shark = 10
print ("Multipliaction:" , WIRE_SHARK*wire_shark)
# Out:
# Multipliaction: 16
# Multipliaction: 1925
# Multipliaction: 70000
# Multipliaction: 265000
# Multipliaction: 1000

# %% [markdown]
# **Division**

# %%
# example1
vpn = 2
VPN = 8
print ("Division:" , vpn/VPN)
# example2
encryption = 35
decryption  = 55
print ("Division:" , encryption/decryption)
# example3
num1 = 700
num2 = 100
print ("Division:" , num1/num2)
# example4
mat_lab = 530
MAT_LAB = 500
print ("Division:" , mat_lab/MAT_LAB)
# example5
WIRE_SHARK = 100
wire_shark = 10
print ("Division:" , WIRE_SHARK/wire_shark)
# Out:
# Division: 0.25
# Division: 0.6363636363636364
# Division: 7.0
# Division: 1.06
# Division: 10.0

# %% [markdown]
# **Modulus**

# %%
# example1
mercury = 10
MERCURY = 3
print ("Modulus:" , mercury%MERCURY)
# example2
venus = 20
VENUS  = 3
print ("Modulus:" , venus%VENUS)
# example3
earth = 70
EARTH = 4
print ("Modulus:" , earth%EARTH)
# example4
mars = 50
MARS = 2
print ("Modulus:" , mars%MARS)
# example5
pluto = 10
PLUTO = 2
print ("Modulus:" , pluto%PLUTO)
# Out:
# Modulus: 1
# Modulus: 2
# Modulus: 2
# Modulus: 0
# Modulus: 0

# %% [markdown]
# **Assignment Operators**

# %% [markdown]
# **Assignment (=)**

# %%
# example1
mercury = 10
print ("Assignment:" , mercury)
# example2
venus = 20
print ("Assignment:" , venus)
# example3
earth = 70
print ("Assignment:" , earth)
# example4
mars = 50
print ("Assignment:" , mars)
# example5
PLUTO = 2
print ("Assignment:" , PLUTO)
# Out:
# Assignment: 10
# Assignment: 20
# Assignment: 70
# Assignment: 50
# Assignment: 2

# %% [markdown]
# **Addition Assignment (+=)**

# %%
# example1
big = 5
big +=5
print ("Addition Assignment:" , big)
# example2
bang = 20
bang +=10
print ("Addition Assignment:" , bang)
# example3
spiral = 70
spiral += 10
print ("Addition Assignment:" , spiral)
# example4
metter = 50
metter += 5
print ("Addition Assignment:" , metter)
# example5
universe = 2
universe += 3
print ("Addition Assignment:" , universe)
# Out:
# Addition Assignment: 10
# Addition Assignment: 30
# Addition Assignment: 80
# Addition Assignment: 55
# Addition Assignment: 5

# %% [markdown]
# **Subtraction Assignment (-=)**

# %%
# example1
mercury = 5
mercury -=5
print ("Subtraction Assignment:" , mercury)
# example2
venus = 20
venus -=10
print ("Subtraction Assignment:" , venus)
# example3
earth = 70
earth -= 10
print ("Subtraction Assignment:" , earth)
# example4
mars = 50
mars -= 5
print ("Subtraction Assignment:" , mars)
# example5
pluto = 2
pluto -= 3
print ("Subtraction Assignment:" , pluto)
# Out:
# Subtraction Assignment: 0
# Subtraction Assignment: 10
# Subtraction Assignment: 60
# Subtraction Assignment: 45
# Subtraction Assignment: -1

# %% [markdown]
# Multiplication Assignment (*=) **bold text**

# %%
# example1
jupiter = 5
jupiter *=5
print ("Multiplication Assignment:" , jupiter)
# example2
neptune = 20
neptune *=10
print ("Multiplication Assignment:" , neptune)
# example3
num = 70
num *= 10
print ("Multiplication Assignment:" , num)
# example4
meta = 50
meta *= 5
print ("Multiplication Assignment:" , meta)
# example5
meteoride = 2
meteoride *= 3
print ("Multiplication Assignment:" , meteoride)
# Out:
# Multiplication Assignment: 25
# Multiplication Assignment: 200
# Multiplication Assignment: 700
# Multiplication Assignment: 250
# Multiplication Assignment: 6

# %% [markdown]
# **Division Assignment (/=)**

# %%
# example1
galaxy = 5
galaxy /=5
print ("Division Assignment:" , galaxy)
# example2
alien = 20
alien /=10
print ("Division Assignment:" , alien)
# example3
evo = 70
evo /= 10
print ("Division Assignment:" , evo)
# example4
planet = 50
planet /= 5
print ("Division Assignment:" , planet)
# example5
nebula = 2
nebula /= 3
print ("Division Assignment:" , nebula)
# Out:
# Division Assignment: 1.0
# Division Assignment: 2.0
# Division Assignment: 7.0
# Division Assignment: 10.0
# Division Assignment: 0.6666666666666666

# %% [markdown]
# **Modulus Assignment (%=)**

# %%
# example1
sun = 5
sun %=5
print ("Modulus Assignment:" , sun)
# example2
moon = 20
moon %=10
print ("Modulus Assignment:" , moon)
# example3
apes = 70
apes %= 10
print ("Modulus Assignment:" , apes)
# example4
robot = 50
robot %= 5
print ("Modulus Assignment:" , robot)
# example5
rover = 2
rover %= 3
print ("Modulus Assignment:" , rover)
# Out:
# Modulus Assignment: 0
# Modulus Assignment: 0
# Modulus Assignment: 0
# Modulus Assignment: 0
# Modulus Assignment: 2
